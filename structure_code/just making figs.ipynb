# %%
import localclassnew as lc
import confignew as cf
import numpy as np
import matplotlib.pyplot as plt



s = lc.States(3,0.5,4,1,1)
fig = s.createimage()
plt.savefig('situation2.png')

# %%
s.splitline()
t = s.copy()
t.spins_to_pattern()
s.createimage()

# %%
s = t.copy()

# %%
fig = s.createimage()
plt.savefig('situation3.png')

# %%
s.local_update()
s.createimage()

# %%
fig = s.createimage()
plt.savefig('situation1.png')
